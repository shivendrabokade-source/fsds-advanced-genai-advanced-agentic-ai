# %% [raw]
# -list
# -tuple
# -set
# -dict
# -range

# %%
l=[]
l
# Out:
# []

# %%
len(l)
# Out:
# 0

# %%
l1=[10,20,30]
l1
# Out:
# [10, 20, 30]

# %%
len(l1)
# Out:
# 3

# %%
l1.append(40)
l1.append(50)
l1.append(60)
l1.append(10)

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 40, 50, 60, 10]

# %%
len(l1)
# Out:
# 6

# %%
l1.append(70,80)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 l1.append(70,80)
#
# TypeError: list.append() takes exactly one argument (2 given)

# %%
l1.append(['a','b','c'])

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 40, 50, 60, 10, ['a', 'b', 'c']]

# %%
l2=[34,5.3,'prakash', 1+2j, True]

# %%
l2
# Out:
# [34, 5.3, 'prakash', (1+2j), True]

# %%
print (l)
print (l1)
print (l2)
# Out:
# []
# [10, 20, 30, 40, 50, 60, 40, 50, 60, 10, ['a', 'b', 'c']]
# [34, 5.3, 'prakash', (1+2j), True]

# %%
print (len(l))
print (len(l1))
print (len(l2))
# Out:
# 0
# 11
# 5

# %%
print (id(l))
print (id(l1))
print (id(l2))
# Out:
# 3067322215232
# 3067322256192
# 3067329921472

# %%
print (type(l))
print (type(l1))
print (type(l2))
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>

# %%
['a','b','c'] in l1
# Out:
# True

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 40, 50, 60, 10, ['a', 'b', 'c']]

# %%
100 in l1
# Out:
# False

# %%
l2
# Out:
# [34, 5.3, 'prakash', (1+2j), True]

# %%
l3 =l2.copy()

# %%
l3
# Out:
# [34, 5.3, 'prakash', (1+2j), True]

# %%
print(id(l2))
print(id(l3))
# Out:
# 3067329921472
# 3067330257920

# %%
print ((l))
print ((l1))
print ((l2))
print ((l3))
# Out:
# []
# [10, 20, 30, 40, 50, 60, 40, 50, 60, 10, ['a', 'b', 'c']]
# [34, 5.3, 'prakash', (1+2j), True]
# [34, 5.3, 'prakash', (1+2j), True]

# %%
l3
# Out:
# [34, 5.3, 'prakash', (1+2j), True]

# %%
l3.clear()

# %%
l3
# Out:
# []

# %%
del l3

# %%
del l3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 del l3
#
# NameError: name 'l3' is not defined

# %%
print ((l))
print ((l1))
print ((l2))
# Out:
# []
# [10, 20, 30, 40, 50, 60, 40, 50, 60, 10, ['a', 'b', 'c']]
# [34, 5.3, 'prakash', (1+2j), True]

# %%
l2.count(5.3)
# Out:
# 1

# %%
l1.count(10)
# Out:
# 2

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 40, 50, 60, 10, ['a', 'b', 'c']]

# %%
l1[:]
# Out:
# [10, 20, 30, 40, 50, 60, 40, 50, 60, 10, ['a', 'b', 'c']]

# %%
l1[-1]
# Out:
# ['a', 'b', 'c']

# %%
l1[100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 l1[100]
#
# IndexError: list index out of range

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 40, 50, 60, 10, ['a', 'b', 'c']]

# %%
l1[4:]
# Out:
# [50, 60, 40, 50, 60, 10, ['a', 'b', 'c']]

# %%
l1[3:-1]
# Out:
# [40, 50, 60, 40, 50, 60, 10]

# %%
l1[0:10:3]
# Out:
# [10, 40, 40, 10]

# %%
l1[::1]
# Out:
# [10, 20, 30, 40, 50, 60, 40, 50, 60, 10, ['a', 'b', 'c']]

# %%
l1[::2]
# Out:
# [10, 30, 50, 40, 60, ['a', 'b', 'c']]

# %%
l1[::3]
# Out:
# [10, 40, 40, 10]

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 40, 50, 60, 10, ['a', 'b', 'c']]

# %%
l1[::-1]
# Out:
# [['a', 'b', 'c'], 10, 60, 50, 40, 60, 50, 40, 30, 20, 10]

# %%
l1[::-2]
# Out:
# [['a', 'b', 'c'], 60, 40, 50, 30, 10]

# %%
l1[::-3]
# Out:
# [['a', 'b', 'c'], 50, 50, 20]

# %%
l1[4:-3]
# Out:
# [50, 60, 40, 50]

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 40, 50, 60, 10, ['a', 'b', 'c']]
